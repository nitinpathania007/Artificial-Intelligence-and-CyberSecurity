# %%
import boto3
import numpy as np
import os
import pathlib
import random
import tensorflow as tf
import time
import sagemaker

from keras.preprocessing.image import img_to_array, load_img
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.tensorflow import TensorFlow
from sklearn.model_selection import train_test_split
from sagemaker.tuner import ContinuousParameter, HyperparameterTuner
from sagemaker.tensorflow.serving import Model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Converting images to the TFRecord format

# %% [markdown]
# ## Get all image paths and shuffle them

# %%
data_root = pathlib.Path(os.path.join(os.getcwd(), 'images'))

# %%
all_image_paths = list(data_root.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
random.shuffle(all_image_paths)
image_count = len(all_image_paths)

# %%
all_image_paths[:10]
# Out:
# ['/home/ec2-user/SageMaker/images/1/14154_idx5_x2151_y1401_class1.png',
#  '/home/ec2-user/SageMaker/images/0/16165_idx5_x2751_y151_class0.png',
#  '/home/ec2-user/SageMaker/images/0/16085_idx5_x501_y1701_class0.png',
#  '/home/ec2-user/SageMaker/images/0/14192_idx5_x2501_y401_class0.png',
#  '/home/ec2-user/SageMaker/images/1/10293_idx5_x901_y1901_class1.png',
#  '/home/ec2-user/SageMaker/images/1/12822_idx5_x1301_y151_class1.png',
#  '/home/ec2-user/SageMaker/images/0/10307_idx5_x2401_y651_class0.png',
#  '/home/ec2-user/SageMaker/images/0/12891_idx5_x2851_y1001_class0.png',
#  '/home/ec2-user/SageMaker/images/1/13462_idx5_x1501_y1601_class1.png',
#  '/home/ec2-user/SageMaker/images/1/13692_idx5_x2251_y601_class1.png']

# %% [markdown]
# ## Get all image labels

# %%
all_image_labels = [int(pathlib.Path(path).parent.name) for path in all_image_paths]

# %%
all_image_labels[:10]
# Out:
# [1, 0, 0, 0, 1, 1, 0, 0, 1, 1]

# %% [markdown]
# ## Get a numpy array containing all images with their associated labels

# %%
channels = 3
image_height = 50
image_width = 50

# %%
dataset = np.ndarray(shape=(image_count, image_height, image_width, channels),
                     dtype=np.uint8)

i = 0
for file in all_image_paths:
    img = load_img(file)  # this is a PIL image
    img = img.resize((image_width, image_height))
    x = img_to_array(img, 'channels_last') 
    dataset[i] = x
    i += 1
    if i % 250 == 0:
        print("%d images to array" % i)
print("All images to array!")
# Out:
# 250 images to array
# 500 images to array
# 750 images to array
# 1000 images to array
# 1250 images to array
# 1500 images to array
# 1750 images to array
# 2000 images to array
# 2250 images to array
# 2500 images to array
# 2750 images to array
# 3000 images to array
# 3250 images to array
# 3500 images to array
# 3750 images to array
# 4000 images to array
# 4250 images to array
# 4500 images to array
# 4750 images to array
# 5000 images to array
# 5250 images to array
# 5500 images to array
# 5750 images to array
# 6000 images to array
# 6250 images to array
# 6500 images to array
# 6750 images to array
# 7000 images to array
# 7250 images to array
# 7500 images to array
# 7750 images to array
# 8000 images to array
# 8250 images to array
# 8500 images to array
# 8750 images to array
# 9000 images to array
# 9250 images to array
# 9500 images to array
# 9750 images to array
# 10000 images to array
# 10250 images to array
# 10500 images to array
# 10750 images to array
# 11000 images to array
# 11250 images to array
# 11500 images to array
# 11750 images to array
# 12000 images to array
# 12250 images to array
# 12500 images to array
# 12750 images to array
# 13000 images to array
# 13250 images to array
# 13500 images to array
# 13750 images to array
# 14000 images to array
# 14250 images to array
# 14500 images to array
# 14750 images to array
# 15000 images to array
# 15250 images to array
# 15500 images to array
# 15750 images to array
# 16000 images to array
# 16250 images to array
# 16500 images to array
# 16750 images to array
# 17000 images to array
# 17250 images to array
# 17500 images to array
# 17750 images to array
# 18000 images to array
# 18250 images to array
# 18500 images to array
# 18750 images to array
# 19000 images to array
# 19250 images to array
# 19500 images to array
# 19750 images to array
# 20000 images to array
# 20250 images to array
# 20500 images to array
# 20750 images to array
# 21000 images to array
# 21250 images to array
# 21500 images to array
# 21750 images to array
# 22000 images to array
# 22250 images to array
# 22500 images to array
# 22750 images to array
# 23000 images to array
# 23250 images to array
# 23500 images to array
# 23750 images to array
# 24000 images to array
# 24250 images to array
# 24500 images to array
# 24750 images to array
# 25000 images to array
# 25250 images to array
# 25500 images to array
# 25750 images to array
# 26000 images to array
# 26250 images to array
# 26500 images to array
# 26750 images to array
# 27000 images to array
# 27250 images to array
# 27500 images to array
# 27750 images to array
# 28000 images to array
# 28250 images to array
# 28500 images to array
# 28750 images to array
# 29000 images to array
# 29250 images to array
# 29500 images to array
# 29750 images to array
# 30000 images to array
# 30250 images to array
# 30500 images to array
# 30750 images to array
# 31000 images to array
# 31250 images to array
# 31500 images to array
# 31750 images to array
# 32000 images to array
# 32250 images to array
# 32500 images to array
# 32750 images to array
# 33000 images to array
# 33250 images to array
# 33500 images to array
# 33750 images to array
# 34000 images to array
# 34250 images to array
# 34500 images to array
# 34750 images to array
# 35000 images to array
# 35250 images to array
# 35500 images to array
# 35750 images to array
# 36000 images to array
# 36250 images to array
# 36500 images to array
# 36750 images to array
# 37000 images to array
# 37250 images to array
# 37500 images to array
# 37750 images to array
# 38000 images to array
# 38250 images to array
# 38500 images to array
# 38750 images to array
# 39000 images to array
# 39250 images to array
# 39500 images to array
# 39750 images to array
# 40000 images to array
# 40250 images to array
# 40500 images to array
# 40750 images to array
# 41000 images to array
# 41250 images to array
# 41500 images to array
# 41750 images to array
# 42000 images to array
# 42250 images to array
# 42500 images to array
# 42750 images to array
# 43000 images to array
# 43250 images to array
# 43500 images to array
# 43750 images to array
# 44000 images to array
# 44250 images to array
# 44500 images to array
# 44750 images to array
# 45000 images to array
# 45250 images to array
# 45500 images to array
# 45750 images to array
# 46000 images to array
# 46250 images to array
# 46500 images to array
# 46750 images to array
# 47000 images to array
# 47250 images to array
# 47500 images to array
# 47750 images to array
# 48000 images to array
# 48250 images to array
# 48500 images to array
# 48750 images to array
# 49000 images to array
# 49250 images to array
# 49500 images to array
# 49750 images to array
# 50000 images to array
# 50250 images to array
# 50500 images to array
# 50750 images to array
# 51000 images to array
# 51250 images to array
# 51500 images to array
# 51750 images to array
# 52000 images to array
# 52250 images to array
# 52500 images to array
# 52750 images to array
# 53000 images to array
# 53250 images to array
# 53500 images to array
# 53750 images to array
# 54000 images to array
# 54250 images to array
# 54500 images to array
# 54750 images to array
# 55000 images to array
# 55250 images to array
# 55500 images to array
# 55750 images to array
# 56000 images to array
# 56250 images to array
# 56500 images to array
# 56750 images to array
# 57000 images to array
# 57250 images to array
# 57500 images to array
# 57750 images to array
# 58000 images to array
# 58250 images to array
# 58500 images to array
# 58750 images to array
# 59000 images to array
# 59250 images to array
# 59500 images to array
# 59750 images to array
# 60000 images to array
# 60250 images to array
# 60500 images to array
# 60750 images to array
# 61000 images to array
# 61250 images to array
# 61500 images to array
# 61750 images to array
# 62000 images to array
# 62250 images to array
# 62500 images to array
# 62750 images to array
# 63000 images to array
# 63250 images to array
# 63500 images to array
# 63750 images to array
# 64000 images to array
# 64250 images to array
# 64500 images to array
# 64750 images to array
# 65000 images to array
# 65250 images to array
# 65500 images to array
# 65750 images to array
# 66000 images to array
# 66250 images to array
# 66500 images to array
# 66750 images to array
# 67000 images to array
# 67250 images to array
# 67500 images to array
# 67750 images to array
# 68000 images to array
# 68250 images to array
# 68500 images to array
# 68750 images to array
# 69000 images to array
# 69250 images to array
# 69500 images to array
# 69750 images to array
# 70000 images to array
# 70250 images to array
# 70500 images to array
# 70750 images to array
# 71000 images to array
# 71250 images to array
# 71500 images to array
# 71750 images to array
# 72000 images to array
# 72250 images to array
# 72500 images to array
# 72750 images to array
# 73000 images to array
# 73250 images to array
# 73500 images to array
# 73750 images to array
# 74000 images to array
# 74250 images to array
# 74500 images to array
# 74750 images to array
# 75000 images to array
# 75250 images to array
# 75500 images to array
# 75750 images to array
# 76000 images to array
# 76250 images to array
# 76500 images to array
# 76750 images to array
# 77000 images to array
# 77250 images to array
# 77500 images to array
# 77750 images to array
# 78000 images to array
# 78250 images to array
# 78500 images to array
# 78750 images to array
# 79000 images to array
# 79250 images to array
# 79500 images to array
# 79750 images to array
# 80000 images to array
# 80250 images to array
# 80500 images to array
# 80750 images to array
# 81000 images to array
# 81250 images to array
# 81500 images to array
# 81750 images to array
# 82000 images to array
# 82250 images to array
# 82500 images to array
# 82750 images to array
# 83000 images to array
# 83250 images to array
# 83500 images to array
# 83750 images to array
# 84000 images to array
# 84250 images to array
# 84500 images to array
# 84750 images to array
# 85000 images to array
# 85250 images to array
# 85500 images to array
# 85750 images to array
# 86000 images to array
# 86250 images to array
# 86500 images to array
# 86750 images to array
# 87000 images to array
# 87250 images to array
# 87500 images to array
# 87750 images to array
# 88000 images to array
# 88250 images to array
# 88500 images to array
# 88750 images to array
# 89000 images to array
# 89250 images to array
# 89500 images to array
# 89750 images to array
# 90000 images to array
# 90250 images to array
# 90500 images to array
# 90750 images to array
# 91000 images to array
# 91250 images to array
# 91500 images to array
# 91750 images to array
# 92000 images to array
# 92250 images to array
# 92500 images to array
# 92750 images to array
# 93000 images to array
# 93250 images to array
# 93500 images to array
# 93750 images to array
# 94000 images to array
# 94250 images to array
# 94500 images to array
# 94750 images to array
# 95000 images to array
# 95250 images to array
# 95500 images to array
# 95750 images to array
# 96000 images to array
# 96250 images to array
# 96500 images to array
# 96750 images to array
# 97000 images to array
# 97250 images to array
# 97500 images to array
# 97750 images to array
# 98000 images to array
# 98250 images to array
# 98500 images to array
# 98750 images to array
# 99000 images to array
# 99250 images to array
# 99500 images to array
# 99750 images to array
# 100000 images to array
# 100250 images to array
# 100500 images to array
# 100750 images to array
# 101000 images to array
# 101250 images to array
# 101500 images to array
# 101750 images to array
# 102000 images to array
# 102250 images to array
# 102500 images to array
# 102750 images to array
# 103000 images to array
# 103250 images to array
# 103500 images to array
# 103750 images to array
# 104000 images to array
# 104250 images to array
# 104500 images to array
# 104750 images to array
# 105000 images to array
# 105250 images to array
# 105500 images to array
# 105750 images to array
# 106000 images to array
# 106250 images to array
# 106500 images to array
# 106750 images to array
# 107000 images to array
# 107250 images to array
# 107500 images to array
# 107750 images to array
# 108000 images to array
# 108250 images to array
# 108500 images to array
# 108750 images to array
# 109000 images to array
# 109250 images to array
# 109500 images to array
# 109750 images to array
# 110000 images to array
# 110250 images to array
# 110500 images to array
# 110750 images to array
# 111000 images to array
# 111250 images to array
# 111500 images to array
# 111750 images to array
# 112000 images to array
# 112250 images to array
# 112500 images to array
# 112750 images to array
# 113000 images to array
# 113250 images to array
# 113500 images to array
# 113750 images to array
# 114000 images to array
# 114250 images to array
# 114500 images to array
# 114750 images to array
# 115000 images to array
# 115250 images to array
# 115500 images to array
# 115750 images to array
# 116000 images to array
# 116250 images to array
# 116500 images to array
# 116750 images to array
# 117000 images to array
# 117250 images to array
# 117500 images to array
# 117750 images to array
# 118000 images to array
# 118250 images to array
# 118500 images to array
# 118750 images to array
# 119000 images to array
# 119250 images to array
# 119500 images to array
# 119750 images to array
# 120000 images to array
# 120250 images to array
# 120500 images to array
# 120750 images to array
# 121000 images to array
# 121250 images to array
# 121500 images to array
# 121750 images to array
# 122000 images to array
# 122250 images to array
# 122500 images to array
# 122750 images to array
# 123000 images to array
# 123250 images to array
# 123500 images to array
# 123750 images to array
# 124000 images to array
# 124250 images to array
# 124500 images to array
# 124750 images to array
# 125000 images to array
# 125250 images to array
# 125500 images to array
# 125750 images to array
# 126000 images to array
# 126250 images to array
# 126500 images to array
# 126750 images to array
# 127000 images to array
# 127250 images to array
# 127500 images to array
# 127750 images to array
# 128000 images to array
# 128250 images to array
# 128500 images to array
# 128750 images to array
# 129000 images to array
# 129250 images to array
# 129500 images to array
# 129750 images to array
# 130000 images to array
# 130250 images to array
# 130500 images to array
# 130750 images to array
# 131000 images to array
# 131250 images to array
# 131500 images to array
# 131750 images to array
# 132000 images to array
# 132250 images to array
# 132500 images to array
# 132750 images to array
# 133000 images to array
# 133250 images to array
# 133500 images to array
# 133750 images to array
# 134000 images to array
# 134250 images to array
# 134500 images to array
# 134750 images to array
# 135000 images to array
# 135250 images to array
# 135500 images to array
# 135750 images to array
# 136000 images to array
# 136250 images to array
# 136500 images to array
# 136750 images to array
# 137000 images to array
# 137250 images to array
# 137500 images to array
# 137750 images to array
# 138000 images to array
# 138250 images to array
# 138500 images to array
# 138750 images to array
# 139000 images to array
# 139250 images to array
# 139500 images to array
# 139750 images to array
# 140000 images to array
# 140250 images to array
# 140500 images to array
# 140750 images to array
# 141000 images to array
# 141250 images to array
# 141500 images to array
# 141750 images to array
# 142000 images to array
# 142250 images to array
# 142500 images to array
# 142750 images to array
# 143000 images to array
# 143250 images to array
# 143500 images to array
# 143750 images to array
# 144000 images to array
# 144250 images to array
# 144500 images to array
# 144750 images to array
# 145000 images to array
# 145250 images to array
# 145500 images to array
# 145750 images to array
# 146000 images to array
# 146250 images to array
# 146500 images to array
# 146750 images to array
# 147000 images to array
# 147250 images to array
# 147500 images to array
# 147750 images to array
# 148000 images to array
# 148250 images to array
# 148500 images to array
# 148750 images to array
# 149000 images to array
# 149250 images to array
# 149500 images to array
# 149750 images to array
# 150000 images to array
# 150250 images to array
# 150500 images to array
# 150750 images to array
# 151000 images to array
# 151250 images to array
# 151500 images to array
# 151750 images to array
# 152000 images to array
# 152250 images to array
# 152500 images to array
# 152750 images to array
# 153000 images to array
# 153250 images to array
# 153500 images to array
# 153750 images to array
# 154000 images to array
# 154250 images to array
# 154500 images to array
# 154750 images to array
# 155000 images to array
# 155250 images to array
# 155500 images to array
# 155750 images to array
# 156000 images to array
# 156250 images to array
# 156500 images to array
# 156750 images to array
# 157000 images to array
# 157250 images to array
# 157500 images to array
# 157750 images to array
# 158000 images to array
# 158250 images to array
# 158500 images to array
# 158750 images to array
# 159000 images to array
# 159250 images to array
# 159500 images to array
# 159750 images to array
# 160000 images to array
# 160250 images to array
# 160500 images to array
# 160750 images to array
# 161000 images to array
# 161250 images to array
# 161500 images to array
# 161750 images to array
# 162000 images to array
# 162250 images to array
# 162500 images to array
# 162750 images to array
# 163000 images to array
# 163250 images to array
# 163500 images to array
# 163750 images to array
# 164000 images to array
# 164250 images to array
# 164500 images to array
# 164750 images to array
# 165000 images to array
# 165250 images to array
# 165500 images to array
# 165750 images to array
# 166000 images to array
# 166250 images to array
# 166500 images to array
# 166750 images to array
# 167000 images to array
# 167250 images to array
# 167500 images to array
# 167750 images to array
# 168000 images to array
# 168250 images to array
# 168500 images to array
# 168750 images to array
# 169000 images to array
# 169250 images to array
# 169500 images to array
# 169750 images to array
# 170000 images to array
# 170250 images to array
# 170500 images to array
# 170750 images to array
# 171000 images to array
# 171250 images to array
# 171500 images to array
# 171750 images to array
# 172000 images to array
# 172250 images to array
# 172500 images to array
# 172750 images to array
# 173000 images to array
# 173250 images to array
# 173500 images to array
# 173750 images to array
# 174000 images to array
# 174250 images to array
# 174500 images to array
# 174750 images to array
# 175000 images to array
# 175250 images to array
# 175500 images to array
# 175750 images to array
# 176000 images to array
# 176250 images to array
# 176500 images to array
# 176750 images to array
# 177000 images to array
# 177250 images to array
# 177500 images to array
# 177750 images to array
# 178000 images to array
# 178250 images to array
# 178500 images to array
# 178750 images to array
# 179000 images to array
# 179250 images to array
# 179500 images to array
# 179750 images to array
# 180000 images to array
# 180250 images to array
# 180500 images to array
# 180750 images to array
# 181000 images to array
# 181250 images to array
# 181500 images to array
# 181750 images to array
# 182000 images to array
# 182250 images to array
# 182500 images to array
# 182750 images to array
# 183000 images to array
# 183250 images to array
# 183500 images to array
# 183750 images to array
# 184000 images to array
# 184250 images to array
# 184500 images to array
# 184750 images to array
# 185000 images to array
# 185250 images to array
# 185500 images to array
# 185750 images to array
# 186000 images to array
# 186250 images to array
# 186500 images to array
# 186750 images to array
# 187000 images to array
# 187250 images to array
# 187500 images to array
# 187750 images to array
# 188000 images to array
# 188250 images to array
# 188500 images to array
# 188750 images to array
# 189000 images to array
# 189250 images to array
# 189500 images to array
# 189750 images to array
# 190000 images to array
# 190250 images to array
# 190500 images to array
# 190750 images to array
# 191000 images to array
# 191250 images to array
# 191500 images to array
# 191750 images to array
# 192000 images to array
# 192250 images to array
# 192500 images to array
# 192750 images to array
# 193000 images to array
# 193250 images to array
# 193500 images to array
# 193750 images to array
# 194000 images to array
# 194250 images to array
# 194500 images to array
# 194750 images to array
# 195000 images to array
# 195250 images to array
# 195500 images to array
# 195750 images to array
# 196000 images to array
# 196250 images to array
# 196500 images to array
# 196750 images to array
# 197000 images to array
# 197250 images to array
# 197500 images to array
# 197750 images to array
# 198000 images to array
# 198250 images to array
# 198500 images to array
# 198750 images to array
# 199000 images to array
# 199250 images to array
# 199500 images to array
# 199750 images to array
# 200000 images to array
# 200250 images to array
# 200500 images to array
# 200750 images to array
# 201000 images to array
# 201250 images to array
# 201500 images to array
# 201750 images to array
# 202000 images to array
# 202250 images to array
# 202500 images to array
# 202750 images to array
# 203000 images to array
# 203250 images to array
# 203500 images to array
# 203750 images to array
# 204000 images to array
# 204250 images to array
# 204500 images to array
# 204750 images to array
# 205000 images to array
# 205250 images to array
# 205500 images to array
# 205750 images to array
# 206000 images to array
# 206250 images to array
# 206500 images to array
# 206750 images to array
# 207000 images to array
# 207250 images to array
# 207500 images to array
# 207750 images to array
# 208000 images to array
# 208250 images to array
# 208500 images to array
# 208750 images to array
# 209000 images to array
# 209250 images to array
# 209500 images to array
# 209750 images to array
# 210000 images to array
# 210250 images to array
# 210500 images to array
# 210750 images to array
# 211000 images to array
# 211250 images to array
# 211500 images to array
# 211750 images to array
# 212000 images to array
# 212250 images to array
# 212500 images to array
# 212750 images to array
# 213000 images to array
# 213250 images to array
# 213500 images to array
# 213750 images to array
# 214000 images to array
# 214250 images to array
# 214500 images to array
# 214750 images to array
# 215000 images to array
# 215250 images to array
# 215500 images to array
# 215750 images to array
# 216000 images to array
# 216250 images to array
# 216500 images to array
# 216750 images to array
# 217000 images to array
# 217250 images to array
# 217500 images to array
# 217750 images to array
# 218000 images to array
# 218250 images to array
# 218500 images to array
# 218750 images to array
# 219000 images to array
# 219250 images to array
# 219500 images to array
# 219750 images to array
# 220000 images to array
# 220250 images to array
# 220500 images to array
# 220750 images to array
# 221000 images to array
# 221250 images to array
# 221500 images to array
# 221750 images to array
# 222000 images to array
# 222250 images to array
# 222500 images to array
# 222750 images to array
# 223000 images to array
# 223250 images to array
# 223500 images to array
# 223750 images to array
# 224000 images to array
# 224250 images to array
# 224500 images to array
# 224750 images to array
# 225000 images to array
# 225250 images to array
# 225500 images to array
# 225750 images to array
# 226000 images to array
# 226250 images to array
# 226500 images to array
# 226750 images to array
# 227000 images to array
# 227250 images to array
# 227500 images to array
# 227750 images to array
# 228000 images to array
# 228250 images to array
# 228500 images to array
# 228750 images to array
# 229000 images to array
# 229250 images to array
# 229500 images to array
# 229750 images to array
# 230000 images to array
# 230250 images to array
# 230500 images to array
# 230750 images to array
# 231000 images to array
# 231250 images to array
# 231500 images to array
# 231750 images to array
# 232000 images to array
# 232250 images to array
# 232500 images to array
# 232750 images to array
# 233000 images to array
# 233250 images to array
# 233500 images to array
# 233750 images to array
# 234000 images to array
# 234250 images to array
# 234500 images to array
# 234750 images to array
# 235000 images to array
# 235250 images to array
# 235500 images to array
# 235750 images to array
# 236000 images to array
# 236250 images to array
# 236500 images to array
# 236750 images to array
# 237000 images to array
# 237250 images to array
# 237500 images to array
# 237750 images to array
# 238000 images to array
# 238250 images to array
# 238500 images to array
# 238750 images to array
# 239000 images to array
# 239250 images to array
# 239500 images to array
# 239750 images to array
# 240000 images to array
# 240250 images to array
# 240500 images to array
# 240750 images to array
# 241000 images to array
# 241250 images to array
# 241500 images to array
# 241750 images to array
# 242000 images to array
# 242250 images to array
# 242500 images to array
# 242750 images to array
# 243000 images to array
# 243250 images to array
# 243500 images to array
# 243750 images to array
# 244000 images to array
# 244250 images to array
# 244500 images to array
# 244750 images to array
# 245000 images to array
# 245250 images to array
# 245500 images to array
# 245750 images to array
# 246000 images to array
# 246250 images to array
# 246500 images to array
# 246750 images to array
# 247000 images to array
# 247250 images to array
# 247500 images to array
# 247750 images to array
# 248000 images to array
# 248250 images to array
# 248500 images to array
# 248750 images to array
# 249000 images to array
# 249250 images to array
# 249500 images to array
# 249750 images to array
# 250000 images to array
# 250250 images to array
# 250500 images to array
# 250750 images to array
# 251000 images to array
# 251250 images to array
# 251500 images to array
# 251750 images to array
# 252000 images to array
# 252250 images to array
# 252500 images to array
# 252750 images to array
# 253000 images to array
# 253250 images to array
# 253500 images to array
# 253750 images to array
# 254000 images to array
# 254250 images to array
# 254500 images to array
# 254750 images to array
# 255000 images to array
# 255250 images to array
# 255500 images to array
# 255750 images to array
# 256000 images to array
# 256250 images to array
# 256500 images to array
# 256750 images to array
# 257000 images to array
# 257250 images to array
# 257500 images to array
# 257750 images to array
# 258000 images to array
# 258250 images to array
# 258500 images to array
# 258750 images to array
# 259000 images to array
# 259250 images to array
# 259500 images to array
# 259750 images to array
# 260000 images to array
# 260250 images to array
# 260500 images to array
# 260750 images to array
# 261000 images to array
# 261250 images to array
# 261500 images to array
# 261750 images to array
# 262000 images to array
# 262250 images to array
# 262500 images to array
# 262750 images to array
# 263000 images to array
# 263250 images to array
# 263500 images to array
# 263750 images to array
# 264000 images to array
# 264250 images to array
# 264500 images to array
# 264750 images to array
# 265000 images to array
# 265250 images to array
# 265500 images to array
# 265750 images to array
# 266000 images to array
# 266250 images to array
# 266500 images to array
# 266750 images to array
# 267000 images to array
# 267250 images to array
# 267500 images to array
# 267750 images to array
# 268000 images to array
# 268250 images to array
# 268500 images to array
# 268750 images to array
# 269000 images to array
# 269250 images to array
# 269500 images to array
# 269750 images to array
# 270000 images to array
# 270250 images to array
# 270500 images to array
# 270750 images to array
# 271000 images to array
# 271250 images to array
# 271500 images to array
# 271750 images to array
# 272000 images to array
# 272250 images to array
# 272500 images to array
# 272750 images to array
# 273000 images to array
# 273250 images to array
# 273500 images to array
# 273750 images to array
# 274000 images to array
# 274250 images to array
# 274500 images to array
# 274750 images to array
# 275000 images to array
# 275250 images to array
# 275500 images to array
# 275750 images to array
# 276000 images to array
# 276250 images to array
# 276500 images to array
# 276750 images to array
# 277000 images to array
# 277250 images to array
# 277500 images to array
# All images to array!

# %% [markdown]
# ## Split dataset into train and test

# %%
dataset
# Out:
# array([[[[201, 151, 184],
#          [172, 112, 159],
#          [124,  77, 130],
#          ...,
#          [157, 111, 156],
#          [194, 159, 188],
#          [221, 206, 222]],
#
#         [[183, 140, 184],
#          [178, 123, 165],
#          [206, 171, 195],
#          ...,
#          [128,  88, 134],
#          [183, 130, 175],
#          [173, 126, 167]],
#
#         [[114,  77, 133],
#          [162, 117, 160],
#          [178, 146, 178],
#          ...,
#          [184, 138, 178],
#          [164, 116, 160],
#          [169, 110, 158]],
#
#         ...,
#
#         [[173, 121, 166],
#          [185, 131, 173],
#          [128,  81, 132],
#          ...,
#          [173, 108, 148],
#          [201, 146, 181],
#          [187, 107, 145]],
#
#         [[166, 119, 162],
#          [ 97,  61, 116],
#          [142, 101, 148],
#          ...,
#          [192, 117, 159],
#          [203, 116, 154],
#          [153,  90, 136]],
#
#         [[197, 141, 182],
#          [128,  97, 145],
#          [137,  92, 145],
#          ...,
#          [193, 143, 176],
#          [178, 112, 155],
#          [126,  89, 130]]],
#
#
#        [[[206, 127, 166],
#          [207, 122, 165],
#          [205, 125, 166],
#          ...,
#          [240, 231, 236],
#          [226, 212, 220],
#          [240, 237, 239]],
#
#         [[212, 134, 172],
#          [216, 145, 180],
#          [213, 143, 178],
#          ...,
#          [240, 233, 237],
#          [230, 214, 222],
#          [238, 237, 239]],
#
#         [[212, 136, 175],
#          [212, 137, 175],
#          [210, 130, 168],
#          ...,
#          [224, 210, 221],
#          [236, 223, 227],
#          [239, 236, 239]],
#
#         ...,
#
#         [[213, 124, 167],
#          [214, 128, 168],
#          [211, 120, 163],
#          ...,
#          [206, 118, 156],
#          [216, 157, 187],
#          [213, 156, 187]],
#
#         [[220, 144, 180],
#          [205, 124, 165],
#          [214, 128, 165],
#          ...,
#          [216, 151, 185],
#          [215, 153, 188],
#          [207, 121, 160]],
#
#         [[214, 129, 166],
#          [189, 123, 165],
#          [208, 135, 173],
#          ...,
#          [210, 145, 177],
#          [201, 111, 154],
#          [208, 118, 161]]],
#
#
#        [[[210, 179, 204],
#          [222, 171, 198],
#          [225, 181, 201],
#          ...,
#          [218, 153, 181],
#          [223, 174, 200],
#          [198, 134, 172]],
#
#         [[212, 191, 207],
#          [228, 200, 218],
#          [230, 199, 215],
#          ...,
#          [176, 128, 166],
#          [211, 143, 179],
#          [205, 121, 164]],
#
#         [[190, 162, 186],
#          [226, 195, 215],
#          [188, 168, 190],
#          ...,
#          [211, 141, 177],
#          [193, 118, 163],
#          [134,  81, 129]],
#
#         ...,
#
#         [[231, 201, 217],
#          [231, 199, 212],
#          [226, 172, 195],
#          ...,
#          [231, 168, 195],
#          [232, 172, 192],
#          [232, 202, 218]],
#
#         [[231, 175, 194],
#          [229, 174, 196],
#          [234, 184, 205],
#          ...,
#          [225, 163, 189],
#          [233, 210, 221],
#          [227, 196, 213]],
#
#         [[238, 191, 211],
#          [229, 184, 206],
#          [223, 157, 183],
#          ...,
#          [225, 185, 203],
#          [205, 190, 205],
#          [231, 197, 211]]],
#
#
#        ...,
#
#
#        [[[236, 232, 236],
#          [233, 231, 231],
#          [239, 239, 239],
#          ...,
#          [204, 138, 175],
#          [210, 140, 177],
#          [211, 149, 183]],
#
#         [[240, 237, 240],
#          [240, 237, 239],
#          [239, 239, 240],
#          ...,
#          [209, 145, 175],
#          [199, 136, 174],
#          [208, 145, 178]],
#
#         [[239, 237, 239],
#          [240, 241, 241],
#          [240, 240, 241],
#          ...,
#          [209, 146, 183],
#          [199, 126, 165],
#          [207, 142, 178]],
#
#         ...,
#
#         [[207, 190, 211],
#          [183, 158, 182],
#          [210, 166, 187],
#          ...,
#          [197, 130, 167],
#          [205, 139, 176],
#          [184, 120, 159]],
#
#         [[236, 220, 230],
#          [223, 199, 215],
#          [229, 210, 223],
#          ...,
#          [202, 128, 167],
#          [201, 127, 166],
#          [201, 122, 161]],
#
#         [[237, 233, 235],
#          [233, 220, 227],
#          [230, 207, 218],
#          ...,
#          [168, 106, 149],
#          [190, 125, 163],
#          [176, 120, 163]]],
#
#
#        [[[222, 142, 174],
#          [223, 142, 172],
#          [231, 161, 187],
#          ...,
#          [234, 185, 205],
#          [232, 185, 205],
#          [233, 190, 209]],
#
#         [[234, 183, 203],
#          [223, 148, 179],
#          [232, 175, 200],
#          ...,
#          [235, 193, 210],
#          [235, 184, 207],
#          [234, 193, 209]],
#
#         [[227, 155, 183],
#          [227, 158, 182],
#          [235, 182, 203],
#          ...,
#          [235, 186, 204],
#          [236, 193, 213],
#          [232, 191, 209]],
#
#         ...,
#
#         [[232, 163, 189],
#          [234, 166, 189],
#          [234, 176, 201],
#          ...,
#          [229, 174, 198],
#          [226, 150, 178],
#          [230, 160, 185]],
#
#         [[229, 162, 191],
#          [231, 166, 192],
#          [232, 165, 193],
#          ...,
#          [231, 177, 197],
#          [227, 148, 180],
#          [232, 171, 197]],
#
#         [[231, 157, 184],
#          [231, 171, 197],
#          [230, 154, 184],
#          ...,
#          [231, 168, 194],
#          [225, 159, 185],
#          [232, 175, 196]]],
#
#
#        [[[246, 243, 240],
#          [243, 242, 244],
#          [240, 236, 237],
#          ...,
#          [208, 156, 195],
#          [212, 169, 202],
#          [186, 129, 167]],
#
#         [[240, 240, 244],
#          [240, 239, 241],
#          [244, 240, 240],
#          ...,
#          [205, 148, 184],
#          [225, 201, 211],
#          [240, 227, 228]],
#
#         [[244, 242, 242],
#          [241, 241, 240],
#          [243, 240, 242],
#          ...,
#          [226, 202, 221],
#          [242, 239, 238],
#          [242, 238, 241]],
#
#         ...,
#
#         [[242, 233, 235],
#          [189, 160, 151],
#          [160, 116,  95],
#          ...,
#          [242, 241, 241],
#          [242, 241, 241],
#          [242, 241, 242]],
#
#         [[238, 239, 242],
#          [238, 233, 235],
#          [237, 225, 227],
#          ...,
#          [241, 241, 241],
#          [241, 241, 241],
#          [242, 241, 242]],
#
#         [[229, 221, 230],
#          [233, 229, 233],
#          [240, 241, 237],
#          ...,
#          [241, 241, 241],
#          [242, 241, 241],
#          [242, 241, 242]]]], dtype=uint8)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, all_image_labels, test_size=0.3, random_state=33)

# %% [markdown]
# ## Convert images

# %%
def convert_to_tfrecord(images, labels, num_examples, name, directory):
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))

    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

    if images.shape[0] != num_examples:
        raise ValueError('Images size %d does not match label size %d.' % (images.shape[0], num_examples))
    rows = images.shape[1]
    cols = images.shape[2]
    depth = images.shape[3]

    filename = os.path.join(directory, name + '.tfrecords')
    print('Writing', filename)
    writer = tf.python_io.TFRecordWriter(filename)
    for index in range(num_examples):
        image_raw = images[index].tobytes()
        example = tf.train.Example(features=tf.train.Features(feature={
            'height': _int64_feature(rows),
            'width': _int64_feature(cols),
            'depth': _int64_feature(depth),
            'label': _int64_feature(labels[index]),
            'image_raw': _bytes_feature(image_raw)}))
        writer.write(example.SerializeToString())
    writer.close()

# %%
convert_to_tfrecord(X_train, y_train, len(y_train), 'images_train', os.getcwd())
# Out:
# Writing /home/ec2-user/SageMaker/images_train.tfrecords

# %%
convert_to_tfrecord(X_test, y_test, len(y_test), 'images_test', os.getcwd())
# Out:
# Writing /home/ec2-user/SageMaker/images_test.tfrecords

# %% [markdown]
# ## Upload the train and test .tfrecords files to S3

# %%
# %%bash
#
# aws s3 cp images_train.tfrecords s3://nitinproject1/breast-cancer-detection/input/tfrecord/train/
# aws s3 cp images_test.tfrecords s3://nitinproject1/breast-cancer-detection/input/tfrecord/test/
# Out:
# upload: ./images_train.tfrecords to s3://nitinproject1/breast-cancer-detection/input/tfrecord/train/images_train.tfrecords
# upload: ./images_test.tfrecords to s3://nitinproject1/breast-cancer-detection/input/tfrecord/test/images_test.tfrecords

# %% [markdown]
# # Creating a model using Tensorflow

# %% [markdown]
# ## Configure hyperparameters

# %%
# Number of output classes
num_classes = 2

# Batch size for training
mini_batch_size =  128

# Max steps for training
max_steps = 5000

# Learning rate
learning_rate = 0.01

# %% [markdown]
# ## Create a unique job name

# %%
job_name_prefix = 'breast-cancer-detection'
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
job_name = job_name_prefix + timestamp

# %% [markdown]
# ## Specify the input paths for the job

# %%
bucket = 'nitinproject1'
input_prefix = 'breast-cancer-detection/input/tfrecord'
input_train = 's3://{}/{}/train/'.format(bucket, input_prefix)
input_test = 's3://{}/{}/test/'.format(bucket, input_prefix)

# %% [markdown]
# ## Specify the output path for the job

# %%
output_prefix = 'breast-cancer-detection/output'
output_path = 's3://{}/{}/'.format(bucket, output_prefix)

# %% [markdown]
# ## Configure training instances

# %%
instance_count = 1
instance_type = 'ml.p2.xlarge'
volume_size_gb = 50

# %% [markdown]
# ## Get the execution role

# %%
role = get_execution_role()

# %% [markdown]
# ## Configure train timeout

# %%
train_timeout = 360000

# %% [markdown]
# ## Specify the path to the training script

# %%
training_script_path = 'tensorflowScript.py'

# %% [markdown]
# ## Create a sagemaker.TensorFlow estimator

# %%
estimator = TensorFlow(entry_point=training_script_path,
                       role=role,
                       train_instance_count=instance_count,
                       train_instance_type=instance_type,
                       train_volume_size=volume_size_gb,
                       train_max_run=train_timeout,
                       model_dir=output_path,
                       output_path=output_path,
                       framework_version='1.12.0',
                       py_version = 'py3',
                       hyperparameters = {
                           'num-classes': num_classes,
                           'mini-batch-size': mini_batch_size,
                           'max-steps': max_steps,
                           'learning-rate': learning_rate
                       },
                       metric_definitions = [
                           {
                               'Name': 'loss',
                               'Regex': 'loss = ([0-9\\.]+)'
                           }
                       ])

# %% [markdown]
# # Create a training job

# %%
estimator.fit({
    'train': input_train,
    'test': input_test
}, job_name = job_name)
# Out:
# 2019-06-13 15:40:09 Starting - Starting the training job...
# 2019-06-13 15:40:10 Starting - Launching requested ML instances.........
# 2019-06-13 15:41:41 Starting - Preparing the instances for training......
# 2019-06-13 15:42:51 Downloading - Downloading input data......
# 2019-06-13 15:44:11 Training - Downloading the training image..
# 2019-06-13 15:44:19,553 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2019-06-13 15:44:20,276 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "num-classes": 2,
#         "learning-rate": 0.01,
#         "max-steps": 5000,
#         "model_dir": "s3://sagemaker-data-jv/breast-cancer-detection/output/",
#         "mini-batch-size": 128
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "breast-cancer-detection-2019-06-13-15-40-03",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-data-jv/breast-cancer-detection-2019-06-13-15-40-03/source/sourcedir.tar.gz",
#     "module_name": "tensorflowScript",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "tensorflowScript.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"learning-rate":0.01,"max-steps":5000,"mini-batch-size":128,"model_dir":"s3://sagemaker-data-jv/breast-cancer-detection/output/","num-classes":2}
# SM_USER_ENTRY_POINT=tensorflowScript.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=tensorflowScript
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-data-jv/breast-cancer-detection-2019-06-13-15-40-03/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"learning-rate":0.01,"max-steps":5000,"mini-batch-size":128,"model_dir":"s3://sagemaker-data-jv/breast-cancer-detection/output/","num-classes":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"breast-cancer-detection-2019-06-13-15-40-03","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-data-jv/breast-cancer-detection-2019-06-13-15-40-03/source/sourcedir.tar.gz","module_name":"tensorflowScript","network_interface_name":"ethwe","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"},"user_entry_point":"tensorflowScript.py"}
# SM_USER_ARGS=["--learning-rate","0.01","--max-steps","5000","--mini-batch-size","128","--model_dir","s3://sagemaker-data-jv/breast-cancer-detection/output/","--num-classes","2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_NUM-CLASSES=2
# SM_HP_LEARNING-RATE=0.01
# SM_HP_MAX-STEPS=5000
# SM_HP_MODEL_DIR=s3://sagemaker-data-jv/breast-cancer-detection/output/
# SM_HP_MINI-BATCH-SIZE=128
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python tensorflowScript.py --learning-rate 0.01 --max-steps 5000 --mini-batch-size 128 --model_dir s3://sagemaker-data-jv/breast-cancer-detection/output/ --num-classes 2
#
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp4gz_wqt9
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp4gz_wqt9', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe2d029fcf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# WARNING:tensorflow:From tensorflowScript.py:106: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:276: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:188: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:197: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:197: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From tensorflowScript.py:87: TFRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# WARNING:tensorflow:From tensorflowScript.py:109: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp4gz_wqt9/model.ckpt.
# INFO:tensorflow:loss = 0.7388618, step = 0
#
# 2019-06-13 15:44:15 Training - Training image download completed. Training in progress.INFO:tensorflow:global_step/sec: 36.4447
# INFO:tensorflow:loss = 0.55575454, step = 100 (2.744 sec)
# INFO:tensorflow:global_step/sec: 36.6191
# INFO:tensorflow:loss = 0.59828985, step = 200 (2.731 sec)
# INFO:tensorflow:global_step/sec: 37.562
# INFO:tensorflow:loss = 0.61382616, step = 300 (2.662 sec)
# INFO:tensorflow:global_step/sec: 37.4797
# INFO:tensorflow:loss = 0.5536806, step = 400 (2.668 sec)
# INFO:tensorflow:global_step/sec: 37.4923
# INFO:tensorflow:loss = 0.58829117, step = 500 (2.667 sec)
# INFO:tensorflow:global_step/sec: 37.2925
# INFO:tensorflow:loss = 0.54433995, step = 600 (2.681 sec)
# INFO:tensorflow:global_step/sec: 37.4782
# INFO:tensorflow:loss = 0.5853925, step = 700 (2.668 sec)
# INFO:tensorflow:global_step/sec: 36.954
# INFO:tensorflow:loss = 0.55538493, step = 800 (2.706 sec)
# INFO:tensorflow:global_step/sec: 37.1781
# INFO:tensorflow:loss = 0.57338464, step = 900 (2.690 sec)
# INFO:tensorflow:global_step/sec: 37.3238
# INFO:tensorflow:loss = 0.5798443, step = 1000 (2.679 sec)
# INFO:tensorflow:global_step/sec: 36.6733
# INFO:tensorflow:loss = 0.61094064, step = 1100 (2.727 sec)
# INFO:tensorflow:global_step/sec: 36.931
# INFO:tensorflow:loss = 0.59558487, step = 1200 (2.708 sec)
# INFO:tensorflow:global_step/sec: 37.2374
# INFO:tensorflow:loss = 0.6472969, step = 1300 (2.686 sec)
# INFO:tensorflow:global_step/sec: 37.3409
# INFO:tensorflow:loss = 0.5471941, step = 1400 (2.678 sec)
# INFO:tensorflow:global_step/sec: 36.9904
# INFO:tensorflow:loss = 0.5948458, step = 1500 (2.703 sec)
# INFO:tensorflow:global_step/sec: 37.3526
# INFO:tensorflow:loss = 0.6438659, step = 1600 (2.677 sec)
# INFO:tensorflow:global_step/sec: 37.0707
# INFO:tensorflow:loss = 0.6388532, step = 1700 (2.698 sec)
# INFO:tensorflow:global_step/sec: 37.4092
# INFO:tensorflow:loss = 0.5716489, step = 1800 (2.673 sec)
# INFO:tensorflow:global_step/sec: 37.5303
# INFO:tensorflow:loss = 0.5545868, step = 1900 (2.665 sec)
# INFO:tensorflow:global_step/sec: 37.386
# INFO:tensorflow:loss = 0.6092695, step = 2000 (2.674 sec)
# INFO:tensorflow:global_step/sec: 37.3218
# INFO:tensorflow:loss = 0.53905666, step = 2100 (2.679 sec)
# INFO:tensorflow:global_step/sec: 37.4406
# INFO:tensorflow:loss = 0.63152105, step = 2200 (2.671 sec)
# INFO:tensorflow:global_step/sec: 37.2744
# INFO:tensorflow:loss = 0.62730825, step = 2300 (2.683 sec)
# INFO:tensorflow:global_step/sec: 37.5051
# INFO:tensorflow:loss = 0.6308374, step = 2400 (2.666 sec)
# INFO:tensorflow:global_step/sec: 37.2568
# INFO:tensorflow:loss = 0.55906653, step = 2500 (2.684 sec)
# INFO:tensorflow:global_step/sec: 37.4829
# INFO:tensorflow:loss = 0.5802451, step = 2600 (2.668 sec)
# INFO:tensorflow:global_step/sec: 37.5497
# INFO:tensorflow:loss = 0.6207364, step = 2700 (2.663 sec)
# INFO:tensorflow:global_step/sec: 37.3655
# INFO:tensorflow:loss = 0.55898356, step = 2800 (2.676 sec)
# INFO:tensorflow:global_step/sec: 37.2958
# INFO:tensorflow:loss = 0.59474117, step = 2900 (2.681 sec)
# INFO:tensorflow:global_step/sec: 37.2181
# INFO:tensorflow:loss = 0.5398724, step = 3000 (2.687 sec)
# INFO:tensorflow:global_step/sec: 37.3535
# INFO:tensorflow:loss = 0.55061245, step = 3100 (2.677 sec)
# INFO:tensorflow:global_step/sec: 37.2783
# INFO:tensorflow:loss = 0.61524767, step = 3200 (2.682 sec)
# INFO:tensorflow:global_step/sec: 37.2314
# INFO:tensorflow:loss = 0.63033426, step = 3300 (2.686 sec)
# INFO:tensorflow:global_step/sec: 37.3301
# INFO:tensorflow:loss = 0.5797718, step = 3400 (2.679 sec)
# INFO:tensorflow:global_step/sec: 37.2365
# INFO:tensorflow:loss = 0.62388873, step = 3500 (2.686 sec)
# INFO:tensorflow:global_step/sec: 37.2694
# INFO:tensorflow:loss = 0.58678347, step = 3600 (2.683 sec)
# INFO:tensorflow:global_step/sec: 37.4251
# INFO:tensorflow:loss = 0.58072215, step = 3700 (2.672 sec)
# INFO:tensorflow:global_step/sec: 37.2841
# INFO:tensorflow:loss = 0.61665034, step = 3800 (2.682 sec)
# INFO:tensorflow:global_step/sec: 37.3656
# INFO:tensorflow:loss = 0.5941528, step = 3900 (2.676 sec)
# INFO:tensorflow:global_step/sec: 37.3555
# INFO:tensorflow:loss = 0.58754975, step = 4000 (2.677 sec)
# INFO:tensorflow:global_step/sec: 37.2383
# INFO:tensorflow:loss = 0.54789627, step = 4100 (2.685 sec)
# INFO:tensorflow:global_step/sec: 37.0789
# INFO:tensorflow:loss = 0.5586296, step = 4200 (2.697 sec)
# INFO:tensorflow:global_step/sec: 37.2658
# INFO:tensorflow:loss = 0.63320434, step = 4300 (2.683 sec)
# INFO:tensorflow:global_step/sec: 37.3934
# INFO:tensorflow:loss = 0.6014224, step = 4400 (2.674 sec)
# INFO:tensorflow:global_step/sec: 37.532
# INFO:tensorflow:loss = 0.6569073, step = 4500 (2.664 sec)
# INFO:tensorflow:global_step/sec: 37.2355
# INFO:tensorflow:loss = 0.5726693, step = 4600 (2.686 sec)
# INFO:tensorflow:global_step/sec: 37.3202
# INFO:tensorflow:loss = 0.61494017, step = 4700 (2.679 sec)
# INFO:tensorflow:global_step/sec: 37.57
# INFO:tensorflow:loss = 0.56559706, step = 4800 (2.662 sec)
# INFO:tensorflow:global_step/sec: 37.4419
# INFO:tensorflow:loss = 0.6310422, step = 4900 (2.671 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp4gz_wqt9/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-06-13-15:46:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp4gz_wqt9/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [500/5000]
# INFO:tensorflow:Evaluation [1000/5000]
# INFO:tensorflow:Evaluation [1500/5000]
# INFO:tensorflow:Evaluation [2000/5000]
# INFO:tensorflow:Evaluation [2500/5000]
# INFO:tensorflow:Evaluation [3000/5000]
# INFO:tensorflow:Evaluation [3500/5000]
# INFO:tensorflow:Evaluation [4000/5000]
# INFO:tensorflow:Evaluation [4500/5000]
# INFO:tensorflow:Evaluation [5000/5000]
# INFO:tensorflow:Finished evaluation at 2019-06-13-15:48:40
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.71370155, global_step = 5000, loss = 0.59941536
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /tmp/tmp4gz_wqt9/model.ckpt-5000
# INFO:tensorflow:Loss for final step: 0.51770675.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predictions', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from /tmp/tmp4gz_wqt9/model.ckpt-5000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/estimator/estimator.py:1046: calling SavedModelBuilder.add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /opt/ml/model/temp-b'1560440920'/saved_model.pb
# 2019-06-13 15:48:40,827 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2019-06-13 15:49:31 Uploading - Uploading generated training model
# 2019-06-13 15:49:31 Completed - Training job completed
# Billable seconds: 400

# %% [markdown]
# # Creating a tuning job

# %% [markdown]
# ## Defining tuning configuration

# %%
hyperparameter_ranges = {
    'learning_rate': ContinuousParameter(0.001, 1.0)
}
objective_metric_name = 'loss'
objective_type = 'Minimize'

max_jobs=2
max_parallel_jobs=2

# %% [markdown]
# ## Create a unique job name

# %%
job_name_prefix = 'bcd-tuning'
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
job_name = job_name_prefix + timestamp

# %% [markdown]
# ## Creating a hyperparameter tuner

# %%
tuner = HyperparameterTuner(estimator=estimator, 
                            objective_metric_name=objective_metric_name, 
                            hyperparameter_ranges=hyperparameter_ranges,
                            objective_type=objective_type, 
                            max_jobs=max_jobs, 
                            max_parallel_jobs=max_parallel_jobs,
                            metric_definitions = [
                                {
                                   'Name': 'loss',
                                   'Regex': 'loss = ([0-9\\.]+)'
                                }
                            ])

# %% [markdown]
# ## Launch the tuning job

# %%
tuner.fit({
    'train': input_train,
    'test': input_test
}, job_name = job_name)
tuner.wait()

# %% [markdown]
# # Deploying the best model found by the tuning job

# %% [markdown]
# ## Get the execution role

# %%
role = get_execution_role()

# %% [markdown]
# ## Configure hosting instances

# %%
instance_count = 1
instance_type = 'ml.m4.xlarge'

# %% [markdown]
# ## Create a unique model name

# %%
model_name_prefix = 'bcd-image-classification-tensorflow'
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
model_name = model_name_prefix + timestamp

# %% [markdown]
# ## Create a Model object

# %%
model_artifacts_s3_path = 's3://nitinproject1/breast-cancer-detection/output/bcd-tuning-2020-05-07-22-59-02-001-03298e08/output/model.tar.gz'
model = Model(
    name=model_name,
    model_data=model_artifacts_s3_path,
    role=role
)

# %% [markdown]
# ## Create a unique endpoint name

# %%
endpoint_name_prefix = 'breast-cancer-detection-ep'
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_name = endpoint_name_prefix + timestamp

# %% [markdown]
# ## Create a model, an endpoint configuration and an endpoint

# %%
predictor = model.deploy(
    endpoint_name=endpoint_name,
    initial_instance_count=instance_count,
    instance_type=instance_type
)
# Out:
# -------------!

# %% [markdown]
# # Testing the deployed model

# %%
def predict_breast_cancer(image):
    response = predictor.predict(image)
    print('Received response is: ', response)
    print('Probabilities for all classes: ', response['predictions'][0]['probabilities'])
    predicted_class = response['predictions'][0]['classes']
    if predicted_class == 0:
        print('Breast cancer not detected')
    else:
        print('Breast cancer detected')

# %% [markdown]
# ## Get images for both classes

# %%
image_with_no_cancer = dataset[np.logical_not(all_image_labels)][0]

# %%
image_with_cancer = dataset[np.logical_not(all_image_labels)][1]

# %% [markdown]
# ## Obtain predictions

# %%
predict_breast_cancer(image_with_no_cancer)
# Out:
# Received response is:  {'predictions': [{'probabilities': [1.0, 0.0], 'classes': 0}]}
# Probabilities for all classes:  [1.0, 0.0]
# Breast cancer not detected

# %%
predict_breast_cancer(image_with_cancer)
# Out:
# Received response is:  {'predictions': [{'probabilities': [1.0, 0.0], 'classes': 0}]}
# Probabilities for all classes:  [1.0, 0.0]
# Breast cancer not detected

# %% [markdown]
# # Deleting endpoint

# %%
sagemaker.Session().delete_endpoint(predictor.endpoint)
